# %% [markdown]
# # CAPE-Churn — Notebook 03: SHAP Explainable AI (XAI)
#
# Computing global SHAP summary plots and local customer waterfall explanations for tree-based XGBoost models.

# %%
import shap
# Calculated dynamically in backend shap_service.py
